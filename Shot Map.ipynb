# %% [markdown]
# import pandas as pd

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
# !pip install mplsoccer
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from mplsoccer import VerticalPitch

# %%
df = pd.read_csv('erling_haaland_2022_understat.csv')

# %%
df.head()
# Out:
#        id  minute       result      X      Y        xG          player h_a  \
# 0  479846      20  MissedShots  0.936  0.503  0.484085  Erling Haaland   a
# 1  479847      35         Goal  0.885  0.500  0.761169  Erling Haaland   a
# 2  479854      64         Goal  0.864  0.405  0.328053  Erling Haaland   a
# 3  479855      69  MissedShots  0.953  0.552  0.526608  Erling Haaland   a
# 4  479856      75  BlockedShot  0.894  0.710  0.066443  Erling Haaland   a
#
#    player_id situation  season  shotType  match_id    h_team           a_team  \
# 0       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 1       8260   Penalty    2022  LeftFoot     18211  West Ham  Manchester City
# 2       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
# 3       8260  OpenPlay    2022      Head     18211  West Ham  Manchester City
# 4       8260  OpenPlay    2022  LeftFoot     18211  West Ham  Manchester City
#
# ...

# %%
df['X'] = df['X'] * 100
df['Y'] = df['Y'] * 100

# %%
df.head()
# Out:
#        id  minute       result          X          Y        xG  \
# 0  479846      20  MissedShots  93.599998  50.299999  0.484085
# 1  479847      35         Goal  88.500000  50.000000  0.761169
# 2  479854      64         Goal  86.400002  40.500000  0.328053
# 3  479855      69  MissedShots  95.300003  55.200001  0.526608
# 4  479856      75  BlockedShot  89.400002  71.000000  0.066443
#
#            player h_a  player_id situation  season  shotType  match_id  \
# 0  Erling Haaland   a       8260  OpenPlay    2022      Head     18211
# 1  Erling Haaland   a       8260   Penalty    2022  LeftFoot     18211
# 2  Erling Haaland   a       8260  OpenPlay    2022  LeftFoot     18211
# 3  Erling Haaland   a       8260  OpenPlay    2022      Head     18211
# 4  Erling Haaland   a       8260  OpenPlay    2022  LeftFoot     18211
#
#      h_team           a_team  h_goals  a_goals                 date  \
# 0  West Ham  Manchester City        0        2  2022-08-07 15:30:00
# ...

# %%
total_shots = df.shape[0]
total_goals = df[df['result'] == 'Goal'].shape[0]
total_xG = df['xG'].sum()
xG_per_shot = total_xG / total_shots
points_average_distance = df['X'].mean()
actual_average_distance= 120 - (df['X'] * 1.2).mean()

# %%
actual_average_distance
# Out:
# np.float64(11.720000401938833)

# %%
background_color = '#0C0D0E'

# %%
import matplotlib.font_manager as font_manager

font_path = 'Arvo-Regular.ttf'
font_props = font_manager.FontProperties(fname=font_path)

# %%
fig = plt.figure(figsize = (8,12))
fig.patch.set_facecolor(background_color)

ax1 = fig.add_axes([0,.7,1,.2])
ax1.set_facecolor(background_color)
ax1.set_xlim(0,1)
ax1.set_ylim(0,1)

ax1.text(
    x = .5,
    y = .85,
    s = 'Erling Haaland',
    fontsize = 20,
    fontproperties = font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)

ax1.text(
    x = .5,
    y = .75,
    s = 'All shots for Man City in PL 2022-23',
    fontsize = 14,
    fontproperties = font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)

ax1.text(
    x = .25,
    y = .5,
    s = 'Low Quality Chance',
    fontsize = 12,
    fontproperties = font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)

ax1.text(
    x = .45,
    y = .27,
    s = 'Goal',
    fontsize = 10,
    fontproperties = font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'right'
)

ax1.text(
    x = .55,
    y = .27,
    s = 'No Goal',
    fontsize = 10,
    fontproperties = font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'left'
)

ax1.scatter(
    x = .47,
    y = .3,
    s = 100,
    color = 'red',
    edgecolor = 'white',
    linewidth = .8,
    alpha = .6
)

ax1.scatter(
    x = .53,
    y = .3,
    s = 100,
    color = background_color,
    edgecolor = 'white',
    linewidth = .8
)

ax1.scatter(
    x = .37,
    y = .53,
    s = 100,
    color = background_color,
    edgecolor = 'white',
    linewidth = .8
)

ax1.scatter(
    x = .42,
    y = .53,
    s = 200,
    color = background_color,
    edgecolor = 'white',
    linewidth = .8
)

ax1.scatter(
    x = .48,
    y = .53,
    s = 300,
    color = background_color,
    edgecolor = 'white',
    linewidth = .8
)

ax1.scatter(
    x = .54,
    y = .53,
    s = 400,
    color = background_color,
    edgecolor = 'white',
    linewidth = .8
)

ax1.scatter(
    x = .6,
    y = .53,
    s = 500,
    color = background_color,
    edgecolor = 'white',
    linewidth = .8
)

ax1.text(
    x = .75,
    y = .5,
    s = 'High Quality Chance',
    fontsize = 12,
    fontproperties = font_props,
    fontweight = 'bold',
    color = 'white',
    ha = 'center'
)


ax2 = fig.add_axes([.05,.25,.9,.5]),ax2.set_facecolor(background_color)

pitch = VerticalPitch(
    pitch_type= 'opta',
    half=True,
    pitch_color = background_color,
    pad_bottom = .5,
    line_color ='white',
    linewidth = .8,
    axis = True,
    label = True
)

pitch.draw(ax=ax2)

ax2.scatter(x = 90, y = points_average_distance,
            s=100, color = 'white', linewidth = .8)

ax2.plot([90,90], [100, points_average_distance], color = 'white', linewidth=2)

ax2.text(
    x=90, y= points_average_distance - 4,
    s=f'Average Distance\n{actual_average_distance:.1f}yards',
    fontsize=10, fontproperties = font_props,
    color ='white', ha = 'center')

for x in df.to_dict(orient = 'records'):
  pitch.scatter(
      x['X'],
      x['Y'],
      s = 300 * x['xG'],
      color ='red' if x['result'] == 'Goal' else background_color,
      ax=ax2,
      alpha = .7,
      linewidth = .8,
      edgecolor = 'white'
  )


ax3 = fig.add_axes([0,.2,1,.05])
ax3.set_facecolor(background_color)

ax3.text(x=.25, y =.5, s = 'Shots', fontsize = 20, fontproperties = font_props, fontweight = 'bold', color ='white', ha ='left')
ax3.text(x=.25, y=0, s=f'{total_shots}', fontsize=16, font_properties = font_props, color ='red', ha = 'left')

ax3.text(x=.38, y =.5, s = 'Goals', fontsize = 20, fontproperties = font_props, fontweight = 'bold', color ='white', ha ='left')
ax3.text(x=.38, y=0, s=f'{total_goals}', fontsize=16, font_properties = font_props, color ='red', ha = 'left')

ax3.text(x=.53, y =.5, s = 'xG', fontsize = 20, fontproperties = font_props, fontweight = 'bold', color ='white', ha ='left')
ax3.text(x=.53, y=0, s=f'{total_xG:.2f}', fontsize=16, font_properties = font_props, color ='red', ha = 'left')

ax3.text(x=.63, y =.5, s = 'xG per Shot', fontsize = 20, fontproperties = font_props, fontweight = 'bold', color ='white', ha ='left')
ax3.text(x=.63, y=0, s=f'{xG_per_shot:.2f}', fontsize=16, font_properties = font_props, color ='red', ha = 'left')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-5e0e777a3b07> in <cell line: 0>()
# ----> 1 fig = plt.figure(figsize = (8,12))
#       2 fig.patch.set_facecolor(background_color)
#       3
#       4 ax1 = fig.add_axes([0,.7,1,.2])
#       5 ax1.set_facecolor(background_color)
#
# NameError: name 'plt' is not defined
